# %%
# Import necessary libraries
import geopandas as gpd
import os

# %%
os.chdir("C:/Users/emshe/Desktop/BRAINSTATION/CAPSTONE/GIT_REPO")

# %%
# Load the shapefiles
zones_gdf = gpd.read_file("DATA/GEOGRAPHIC/ZONE_2023/Zone_2023/Zone_2023.shp")
nbhds_gdf = gpd.read_file("DATA/GEOGRAPHIC/NBHD_2023/Nbhd_2023/Nbhd_2023.shp")

# %%
# Examine shapefiles

gdfs = {"Zones Dataframe":zones_gdf,"Neighborhood dataframe":nbhds_gdf}

for name,df in gdfs.items():
    print(f"\n\nNumber of records in the {name} is: {len(df)}\n")
    print(f"The columns in the {name} are: {df.columns}\n")
    print(f"Sample of records in the {name}:")
    display(zones_gdf.sample(5))
# Out:
# Number of records in the Zones Dataframe is: 521
#
# The columns in the Zones Dataframe are: Index(['OBJECTID', 'METZONE_UI', 'METCODE', 'ZONECODE', 'ZONENAME_E',
#        'ZONENAME_F', 'ZONENAMELO', 'ZONENAME_1', 'YEAR', 'SHAPE_Leng',
#        'SHAPE_Area', 'geometry'],
#       dtype='object')
#
# Sample of records in the Zones Dataframe:
#      OBJECTID METZONE_UI METCODE ZONECODE                       ZONENAME_E  \
# 115       116     106025    1060       25  Mirabel/Oka/Pointe-Calumet etc.
# 253       255     241001    2410       01            West End/Stanley Park
# 500       505     783801    7838       01                       Wetaskiwin
# 416       419     704501    7045       01                    Mingan Sector
# 189       191     164002    1640       02                  St. John's West
#
#                           ZONENAME_F  \
# 115  Mirabel/Oka/Pointe-Calumet etc.
# 253            West End/Parc Stanley
# 500                       Wetaskiwin
# 416                   Secteur Mingan
# 189                 St. John's Ouest
#
#                                             ZONENAMELO  \
# 115  Mirabel/Oka/Pointe-Calumet/ Sainte-Marthe-sur-...
# 253                              West End/Stanley Park
# 500                                         Wetaskiwin
# 416                                      Mingan Sector
# 189                                    St. John's West
#
#                                             ZONENAME_1       YEAR  \
# 115  Mirabel/Oka/Pointe-Calumet/ Sainte-Marthe-sur-... 2023-02-01
# 253                              West End/Parc Stanley 2023-02-01
# 500                                         Wetaskiwin 2022-02-01
# 416                                     Secteur Mingan 2022-02-01
# 189                                   St. John's Ouest 2023-02-01
#
#         SHAPE_Leng    SHAPE_Area  \
# 115  237541.677743  1.625801e+09
# 253   23595.693485  2.227594e+07
# 500   42011.739390  5.384057e+07
# 416  227812.416365  2.704846e+09
# 189   45728.111336  4.941812e+07
#
#                                               geometry
# 115  POLYGON ((-8227848.527 5742937.711, -8225665.0...
# 253  POLYGON ((-13709954.808 6328768.906, -13708979...
# 500  POLYGON ((-12617152.05 6981032.345, -12617151....
# 416  POLYGON ((-7625976.81 6310040.685, -7625906.58...
# 189  POLYGON ((-5869977.762 6034475.028, -5869927.2...
# Number of records in the Neighborhood dataframe is: 986
#
# The columns in the Neighborhood dataframe are: Index(['OBJECTID', 'METNBHD_UI', 'METCODE', 'NBHDCODE', 'NBHDNAME_E',
#        'NBHDNAME_F', 'NBHDNAMELO', 'NBHDNAME_1', 'ZONECODE', 'SHAPE_Leng',
#        'SHAPE_Area', 'geometry'],
#       dtype='object')
#
# Sample of records in the Neighborhood dataframe:
#      OBJECTID METZONE_UI METCODE ZONECODE                     ZONENAME_E  \
# 105       106     106015    1060       15  Baie-d'Urfé/Beaconsfield etc.
# 116       117     106026    1060       26    Blainville/Ste-Thérèse etc.
# 450       454     742201    7422       01                        Lacombe
# 517       522     572001    5720       01                  Victoriaville
# 171       173     140010    1400       10      Northern Surrounding Area
#
#                         ZONENAME_F  \
# 105  Baie-d'Urfé/Beaconsfield etc.
# 116    Blainville/Ste-Thérèse etc.
# 450                        Lacombe
# 517                  Victoriaville
# 171                Périphérie-Nord
#
#                                             ZONENAMELO  \
# 105  Baie-d'Urfé/Beaconsfield/Kirkland/Pointe-Clair...
# 116  Blainville/Sainte-Thérèse/Lorraine/Bois-des-Fi...
# 450                                            Lacombe
# 517                                      Victoriaville
# 171                          Northern Surrounding Area
#
#                                             ZONENAME_1       YEAR  \
# 105  Baie-d'Urfé/Beaconsfield/Kirkland/Pointe-Clair... 2023-02-01
# 116  Blainville/Sainte-Thérèse/Lorraine/Bois-des-Fi... 2023-02-01
# 450                                            Lacombe 2022-02-01
# 517                                      Victoriaville 2023-02-01
# 171                                    Périphérie-Nord 2023-02-01
#
#         SHAPE_Leng    SHAPE_Area  \
# 105   64646.471586  1.719195e+08
# 116  145273.439681  4.324248e+08
# 450   42439.055769  5.876231e+07
# 517  187462.146082  7.915777e+08
# 171  517941.574055  4.988647e+09
#
#                                               geometry
# 105  POLYGON ((-8214117.751 5696709.588, -8214077.1...
# 116  POLYGON ((-8209320.422 5737841.168, -8209319.6...
# 450  POLYGON ((-12658310.565 6889607.847, -12658284...
# 517  POLYGON ((-8006285.957 5800047.011, -8006215.7...
# 171  MULTIPOLYGON (((-7969382.064 5903673.123, -796...
