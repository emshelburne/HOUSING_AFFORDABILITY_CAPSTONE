# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings

# Important functionality for this lesson
from scipy import stats
import statsmodels.api as sm
import os

# %%
os.chdir("C:/Users/emshe/Desktop/BRAINSTATION/CAPSTONE/DATASETS")

# %%
van_rent_df = pd.read_csv("Vancouver_Historical_Average_Rents_by_Bedroom_Type.csv", skiprows = 2, nrows = 34, encoding = 'unicode_escape')
fairview_rent_df = pd.read_csv("South_Granville_Oak_Historical_Average_Rents_by_Bedroom_Type.csv", skiprows = 2, nrows = 15, encoding = 'unicode_escape')
van_vacancy_df = pd.read_csv("Vancouver_Historical_Vacancy_Rates_by_Bedroom_Type.csv", skiprows = 2, nrows = 35, encoding = 'unicode_escape')

# %%
display(van_vacancy_df)
# Out:
#       Unnamed: 0  Bachelor Unnamed: 2  1 Bedroom Unnamed: 4  2 Bedroom  \
# 0   1990 October       0.7         a         0.7         a         1.2
# 1   1991 October       1.8         b         2.1         a         2.6
# 2   1992 October       1.5         a         1.7         a         1.6
# 3   1993 October       0.7         a         1.1         a         1.2
# 4   1994 October       0.9         a         0.8         a         0.7
# 5   1995 October       0.6         a         1.2         a         1.3
# 6   1996 October       1.0         a         1.1         a         1.3
# 7   1997 October       1.9         b         1.6         a         1.6
# 8   1998 October       1.5         a         2.7         a         3.3
# 9   1999 October       1.9         a         2.8         a         2.5
# 10  2000 October       1.2         a         1.3         a         1.7
# 11  2001 October       1.1         a         1.0         a         1.0
# ...
